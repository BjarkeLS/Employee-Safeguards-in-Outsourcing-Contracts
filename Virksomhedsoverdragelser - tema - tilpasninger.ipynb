# %%
import nltk
import nltk
nltk.download('punkt')
import re 
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
import pandas as pd

import os

import json

from nltk.corpus import stopwords
import lemmy
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\blunds\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
pd.__version__
# Out:
# '1.4.3'

# %%
corpus = pd.read_pickle("virksomhedsoverdragelser_tema_tilpasninger.pkl")

# %%
corpus.tail(20)
# Out:
#                                               filename  \
# 303  Bilag E2. 1. del.18-54001-overenskomst-for-spe...
# 304  Bilag E2. 1. del.18-54001-overenskomst-for-spe...
# 305      Bilag E2. 2. del. 3F Arbejdstidsaftalen_0.pdf
# 306  Bilag E3 .Københavns Kommunes retningslinje om...
# 307  Bilag E4 Københavns Kommunes retningslinjer om...
# 308              Bilag 0. Udbudsbetingelser grøn2.docx
# 309  Bilag E1. vilkår og medarbejder der overdrages...
# 310  Bilag E2. 1. del.18-54001-overenskomst-for-spe...
# 311  Bilag E2. 1. del.18-54001-overenskomst-for-spe...
# 312      Bilag E2. 2. del. 3F Arbejdstidsaftalen_0.pdf
# 313  Bilag E3 .Københavns Kommunes retningslinje om...
# 314  Bilag E4 Københavns Kommunes retningslinjer om...
# 315                    16. udbud Udbudsbetingelser.pdf
# 316  Bilag 10 Afgivelse af oplysninger om personale...
# 317          Bilag 10 Oplysningsskema om personale.pdf
# 318                           udbudsbekendtgørelse.pdf
# 319          15. udbud Udbudsbetingelser v01032021.pdf
# 320  Bilag 10 Afgivelse af oplysninger om personale...
# 321          Bilag 10 Oplysningsskema om personale.pdf
# 322                           udbudsbekendtgørelse.pdf
#
#                                                   text  \
# 303  The command `pdftotext C:\Users\blunds\OneDriv...
# 304  The command `pdftotext C:\Users\blunds\OneDriv...
# 305  • i•*\r\nl*w\r\nÅ\r\n\r\nKØBENHAVNSKOMMUNE\r\n...
# 306  The command `pdftotext C:\Users\blunds\OneDriv...
# 307  Retningslinje om rygning i TMF\r\nGodkendt af ...
# 308  2/20\n\n\n\n\n\n\n\nKøbenhavns Kommune\n\nTekn...
# 309  Vejledning om medarbejdere omfattet af udbudde...
# 310  The command `pdftotext C:\Users\blunds\OneDriv...
# 311  The command `pdftotext C:\Users\blunds\OneDriv...
# 312
#
#
#
#
#
#
#
#
# 313  The command `pdftotext C:\Users\blunds\OneDriv...
# 314  Retningslinje om rygning i TMF\r\nGodkendt af ...
# 315  16. udbud af buskørsel\r\nUdbudsbetingelser\r\...
# 316  Bilag 10\r\nAfgivelse af oplysninger om person...
# 317  Oplysninger om personaleforhold\r\nNedenståend...
# 318  EUT/S S28\r\n10/02/2021\r\n70429-2021-DA\r\n\r...
# 319  15. udbud af buskørsel\r\nUdbudsbetingelser\r\...
# 320  Bilag 10\r\nAfgivelse af oplysninger om person...
# 321  Oplysninger om personaleforhold\r\nNedenståend...
# 322  EUT/S S122\r\n28/06/2021\r\n324610-2021-DA\r\n...
#
#                                                filedir  \
# 303  C:\Users\blunds\OneDrive - Roskilde Universite...
# 304  C:\Users\blunds\OneDrive - Roskilde Universite...
# 305  C:\Users\blunds\OneDrive - Roskilde Universite...
# 306  C:\Users\blunds\OneDrive - Roskilde Universite...
# 307  C:\Users\blunds\OneDrive - Roskilde Universite...
# 308  C:\Users\blunds\OneDrive - Roskilde Universite...
# 309  C:\Users\blunds\OneDrive - Roskilde Universite...
# 310  C:\Users\blunds\OneDrive - Roskilde Universite...
# 311  C:\Users\blunds\OneDrive - Roskilde Universite...
# 312  C:\Users\blunds\OneDrive - Roskilde Universite...
# 313  C:\Users\blunds\OneDrive - Roskilde Universite...
# 314  C:\Users\blunds\OneDrive - Roskilde Universite...
# 315  C:\Users\blunds\OneDrive - Roskilde Universite...
# 316  C:\Users\blunds\OneDrive - Roskilde Universite...
# 317  C:\Users\blunds\OneDrive - Roskilde Universite...
# 318  C:\Users\blunds\OneDrive - Roskilde Universite...
# 319  C:\Users\blunds\OneDrive - Roskilde Universite...
# 320  C:\Users\blunds\OneDrive - Roskilde Universite...
# 321  C:\Users\blunds\OneDrive - Roskilde Universite...
# 322  C:\Users\blunds\OneDrive - Roskilde Universite...
#
#                                             clean_text  \
# 303  the command pdftotext c \users\blunds\onedrive...
# 304  the command pdftotext c \users\blunds\onedrive...
# 305  • i•* l*w å københavnskommune koncernservice �...
# 306  the command pdftotext c \users\blunds\onedrive...
# 307  retningslinje om rygning i tmf godkendt af hsu...
# 308  2 20 københavns kommune teknik og miljøforvalt...
# 309  vejledning om medarbejdere omfattet af udbudde...
# 310  the command pdftotext c \users\blunds\onedrive...
# 311  the command pdftotext c \users\blunds\onedrive...
# 312
# 313  the command pdftotext c \users\blunds\onedrive...
# 314  retningslinje om rygning i tmf godkendt af hsu...
# 315  16 udbud af buskørsel udbudsbetingelser udbud ...
# 316  bilag 10 afgivelse af oplysninger om personale...
# 317  oplysninger om personaleforhold nedenstående o...
# 318  eut s s28 10 02 2021 70429 2021 da 1 4 denne b...
# 319  15 udbud af buskørsel udbudsbetingelser udbud ...
# 320  bilag 10 afgivelse af oplysninger om personale...
# 321  oplysninger om personaleforhold nedenstående o...
# 322  eut s s122 28 06 2021 324610 2021 da 1 5 denne...
#
#                                                   word  \
# 303  [the, command, pdftotext, c, \users\blunds\one...
# 304  [the, command, pdftotext, c, \users\blunds\one...
# 305  [•, i•, *, l, *, w, å, københavnskommune, konc...
# 306  [the, command, pdftotext, c, \users\blunds\one...
# 307  [retningslinje, om, rygning, i, tmf, godkendt,...
# 308  [2, 20, københavns, kommune, teknik, og, miljø...
# 309  [vejledning, om, medarbejdere, omfattet, af, u...
# 310  [the, command, pdftotext, c, \users\blunds\one...
# 311  [the, command, pdftotext, c, \users\blunds\one...
# 312                                                 []
# 313  [the, command, pdftotext, c, \users\blunds\one...
# 314  [retningslinje, om, rygning, i, tmf, godkendt,...
# 315  [16, udbud, af, buskørsel, udbudsbetingelser, ...
# 316  [bilag, 10, afgivelse, af, oplysninger, om, pe...
# 317  [oplysninger, om, personaleforhold, nedenståen...
# 318  [eut, s, s28, 10, 02, 2021, 70429, 2021, da, 1...
# 319  [15, udbud, af, buskørsel, udbudsbetingelser, ...
# 320  [bilag, 10, afgivelse, af, oplysninger, om, pe...
# 321  [oplysninger, om, personaleforhold, nedenståen...
# 322  [eut, s, s122, 28, 06, 2021, 324610, 2021, da,...
#
#                                                  lemmy  \
# 303  [the, command, pdftotext, c, \users\blunds\one...
# 304  [the, command, pdftotext, c, \users\blunds\one...
# 305  [•, i•, *, l, *, w, å, københavnskommune, konc...
# 306  [the, command, pdftotext, c, \users\blunds\one...
# 307  [retningslinje, om, rygning, i, tmf, godkende,...
# 308  [2, 20, københavn, kommune, teknik, og, miljøf...
# 309  [vejledning, om, medarbejder, omfatte, af, udb...
# 310  [the, command, pdftotext, c, \users\blunds\one...
# 311  [the, command, pdftotext, c, \users\blunds\one...
# 312                                                 []
# 313  [the, command, pdftotext, c, \users\blunds\one...
# 314  [retningslinje, om, rygning, i, tmf, godkende,...
# 315  [16, udbud, af, buskørsel, udbudsbetingelse, u...
# 316  [bilag, 10, afgivelse, af, oplysning, om, pers...
# 317  [oplysning, om, personaleforhold, nedenstående...
# 318  [eut, s, s28, 10, 02, 2021, 70429, 2021, da, 1...
# 319  [15, udbud, af, buskørsel, udbudsbetingelse, u...
# 320  [bilag, 10, afgivelse, af, oplysning, om, pers...
# 321  [oplysning, om, personaleforhold, nedenstående...
# 322  [eut, s, s122, 28, 06, 2021, 324610, 2021, da,...
#
#                    virksomhedsoverdragelse_2022_filter  \
# 303  [projekt\virksomhedsoverdragelse\dokument, pro...
# 304  [projekt\virksomhedsoverdragelse\dokument, pro...
# 305                                                 []
# 306  [projekt\virksomhedsoverdragelse\dokument, pro...
# 307                                                 []
# 308                          [virksomhedsoverdragelse]
# 309  [virksomhedsoverdragelseslov, virksomhedsoverd...
# 310  [projekt\virksomhedsoverdragelse\dokument, pro...
# 311  [projekt\virksomhedsoverdragelse\dokument, pro...
# 312                                                 []
# 313  [projekt\virksomhedsoverdragelse\dokument, pro...
# 314                                                 []
# 315  [virksomhedsoverdragelseslov, virksomhedsoverd...
# 316  [virksomhedsoverdragelse, virksomhedsoverdrage...
# 317                                                 []
# 318                          [virksomhedsoverdragelse]
# 319  [virksomhedsoverdragelseslov, virksomhedsoverd...
# 320  [virksomhedsoverdragelse, virksomhedsoverdrage...
# 321                                                 []
# 322                          [virksomhedsoverdragelse]
#
#                                             clean_stor tema_2 tema_3_1  ...  \
# 303  The command pdftotext C \Users\blunds\OneDrive...     []       []  ...
# 304  The command pdftotext C \Users\blunds\OneDrive...     []       []  ...
# 305  • i•* l*w Å KØBENHAVNSKOMMUNE Koncernservice �...     []       []  ...
# 306  The command pdftotext C \Users\blunds\OneDrive...     []       []  ...
# 307  Retningslinje om rygning i TMF Godkendt af HSU...     []       []  ...
# 308  2 20 Københavns Kommune Teknik og Miljøforvalt...     []       []  ...
# 309  Vejledning om medarbejdere omfattet af udbudde...     []       []  ...
# 310  The command pdftotext C \Users\blunds\OneDrive...     []       []  ...
# 311  The command pdftotext C \Users\blunds\OneDrive...     []       []  ...
# 312                                                        []       []  ...
# 313  The command pdftotext C \Users\blunds\OneDrive...     []       []  ...
# 314  Retningslinje om rygning i TMF Godkendt af HSU...     []       []  ...
# 315  16 udbud af buskørsel Udbudsbetingelser Udbud ...     []       []  ...
# 316  Bilag 10 Afgivelse af oplysninger om personale...     []       []  ...
# 317  Oplysninger om personaleforhold Nedenstående o...     []       []  ...
# 318  EUT S S28 10 02 2021 70429 2021 DA 1 4 Denne b...     []       []  ...
# 319  15 udbud af buskørsel Udbudsbetingelser Udbud ...     []       []  ...
# 320  Bilag 10 Afgivelse af oplysninger om personale...     []       []  ...
# 321  Oplysninger om personaleforhold Nedenstående o...     []       []  ...
# 322  EUT S S122 28 06 2021 324610 2021 DA 1 5 Denne...     []       []  ...
#
#     tema_28 tema_29                             tema_33_1 tema_33_2  \
# 303      []      []                                    []        []
# 304      []      []                                    []        []
# 305      []      []                                    []        []
# 306      []      []                                    []        []
# 307      []      []  [personalepolitik, personalepolitik]        []
# 308      []      []                                    []        []
# 309      []      []                                    []        []
# 310      []      []                                    []        []
# 311      []      []                                    []        []
# 312      []      []                                    []        []
# 313      []      []                                    []        []
# 314      []      []  [personalepolitik, personalepolitik]        []
# 315      []      []                                    []        []
# 316      []      []                                    []        []
# 317      []      []                                    []        []
# 318      []      []                                    []        []
# 319      []      []                                    []        []
# 320      []      []                                    []        []
# 321      []      []                                    []        []
# 322      []      []                                    []        []
#
#                                   tema_33 tema_34_1 tema_34_kontekst tema_34  \
# 303                                    []        []               []      []
# 304                                    []        []               []      []
# 305                                    []        []               []      []
# 306                                    []        []               []      []
# 307  [personalepolitik, personalepolitik]        []               []      []
# 308                                    []        []               []      []
# 309                                    []        []               []      []
# 310                                    []        []               []      []
# 311                                    []        []               []      []
# 312                                    []        []               []      []
# 313                                    []        []               []      []
# 314  [personalepolitik, personalepolitik]        []               []      []
# 315                                    []        []               []      []
# 316                                    []        []               []      []
# 317                                    []        []               []      []
# 318                                    []        []               []      []
# 319                                    []        []               []      []
# 320                                    []        []               []      []
# 321                                    []        []               []      []
# 322                                    []        []               []      []
#
#     tema_34_kontrol           tema_35
# 303              []                []
# 304              []                []
# 305              []                []
# 306              []                []
# 307              []                []
# 308              []  [arbejdsklausul]
# 309              []                []
# 310              []                []
# 311              []                []
# 312              []                []
# 313              []                []
# 314              []                []
# 315              []                []
# 316              []                []
# 317              []                []
# 318              []                []
# 319              []                []
# 320              []                []
# 321              []                []
# 322              []                []
#
# [20 rows x 69 columns]

# %%
corpus = corpus.drop(columns=['tema_1', 'tema_2','tema_3', 'tema_4', 'tema_5', 'tema_6', 'tema_7', 'tema_8', 'tema_9', 'tema_10', 'tema_11', 
           'tema_12', 'tema_13', 'tema_14', 'tema_15', 'tema_16', 'tema_17', 'tema_18', 'tema_19', 'tema_20', 'tema_21',
          'tema_22', 'tema_23', 'tema_24', 'tema_25', 'tema_26', 'tema_27', 'tema_28', 'tema_29', 'tema_30', 'tema_31', 
          'tema_32_1', 'tema_32_2', 'tema_32', 'tema_33', 'tema_34', 'tema_6_1', 'tema_6_2', 'tema_9_1', 'tema_9_2', 'tema_10_1', 'tema_10_2', 'tema_11_1', 'tema_11_2', 'tema_14_1', 'tema_14_2', 'tema_23_1' ,'tema_23_2', 'tema_24_1', 'tema_24_2', 'tema_25_1', 'tema_25_2', 'tema_27_1', 'tema_27_kontekst'])

# %%
corpus.head(20)
# Out:
#                                                filename  \
# 15                          Udbudsresume 3672982021 pdf
# 151                         Udbudsresume 3672982021 pdf
# 5273  Erhvervslejekontrakt  Bilag 1  plantegning ove...
# 5274  Erhvervslejekontrakt  Bilag 2  stueplan 129286...
# 5275  Erhvervslejekontrakt  Bilag 3  kælderfacilitet...
# 5276  Erhvervslejekontrakt  Bilag 4 Fotooversigt 129...
# 5277  Erhvervslejekontrakt  Bilag 5  Inventarliste o...
# 5278  Erhvervslejekontrakt  Bilag 6  lejeberegning 1...
# 5279  Erhvervslejekontrakt  Byog Boligministeriets c...
# 5280  Kontrakt  Delaftale 1  Madservice Plejecentren...
# 5281  Kontrakt  Delaftale 2  Madservice til visitere...
# 5282  Kontraktbilag 1  Tilbudsliste XLSX 1292862021 ...
# 5283  Kontraktbilag 2  Kravspecifikationer DOCX 1292...
# 5284  Kontraktbilag 3  Kvalitetsstandard DOCX 129286...
# 5285  Kontraktbilag 4  Kommunikation via omsorgssyst...
# 5286  Kontraktbilag 5  Tidsfrist aflevering til UDK ...
# 5287  Kontraktbilag 6  Erhvervslejekontrakt  Carolin...
# 5288  Udbudsbetingelser Madservice DOCX 1292862021 docx
# 5289  Udbudsbilag 1  Delaftale 1  Tilbudsbesvarelse ...
# 5290  Udbudsbilag 2  Delaftale 2  Tilbudsbesvarelse ...
#
#                                                    text  \
# 15    Danmark-København: Reparation, vedligeholdelse...
# 151   Danmark-København: Reparation, vedligeholdelse...
# 5273
#
# 5274  5-592\r\n\r\nCarolineparken - leje af lokaler\...
# 5275  5-592\r\n\r\nCarolineparken - leje af lokaler\...
# 5276
#
# 5277                             Inventarliste pr. m...
# 5278  Bilag 6\r\nErhvervslejekontrakt\r\n\r\nDok.nr....
# 5279  Tjekliste - Erhvervslejeloven\r\nDenne vejledn...
# 5280  Kontrakt Madservice \n\nDelaftale 1 - Plejecen...
# 5281  Kontrakt Madservice \n\nDelaftale 2 – Visitere...
# 5282                                                ...
# 5283  Udbud vedrørende Madservice\t    \n\n         ...
# 5284  Kontraktbilag 3 - Kvalitetsstandard for Madser...
# 5285  Kontraktbilag 4 - Kommunikation via omsorgssys...
# 5286  Servicebrev 06.11.2020 Indberetningsfrister og...
# 5287  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n      ...
# 5288  Udbud\n\n\n\n\n\nLight regimet\n\n\n\nPå lever...
# 5289  Varde Kommune, Udbud af madservice\t\tDelaftal...
# 5290  Varde Kommune, Udbud af madservice\t\txx 2021\...
#
#                                                 filedir  \
# 15    F:\contract-skills-and-performance\Download af...
# 151   F:\contract-skills-and-performance\Download af...
# 5273  F:\contract-skills-and-performance\Download af...
# 5274  F:\contract-skills-and-performance\Download af...
# 5275  F:\contract-skills-and-performance\Download af...
# 5276  F:\contract-skills-and-performance\Download af...
# 5277  F:\contract-skills-and-performance\Download af...
# 5278  F:\contract-skills-and-performance\Download af...
# 5279  F:\contract-skills-and-performance\Download af...
# 5280  F:\contract-skills-and-performance\Download af...
# 5281  F:\contract-skills-and-performance\Download af...
# 5282  F:\contract-skills-and-performance\Download af...
# 5283  F:\contract-skills-and-performance\Download af...
# 5284  F:\contract-skills-and-performance\Download af...
# 5285  F:\contract-skills-and-performance\Download af...
# 5286  F:\contract-skills-and-performance\Download af...
# 5287  F:\contract-skills-and-performance\Download af...
# 5288  F:\contract-skills-and-performance\Download af...
# 5289  F:\contract-skills-and-performance\Download af...
# 5290  F:\contract-skills-and-performance\Download af...
#
#                                              clean_text  \
# 15    danmark københavn reparation vedligeholdelse o...
# 151   danmark københavn reparation vedligeholdelse o...
# 5273
#
# 5274  5 592 carolineparken leje af lokaler storkøkke...
# 5275  5 592 carolineparken leje af lokaler storkøkke...
# 5276
#
# 5277   inventarliste pr marts 2021 unnamed 1 unnamed...
# 5278  bilag 6 erhvervslejekontrakt dok nr 20318 21 s...
# 5279  tjekliste erhvervslejeloven denne vejledning e...
# 5280  kontrakt madservice delaftale 1 plejecentre 23...
# 5281  kontrakt madservice delaftale 2 – visitere hje...
# 5282   vejledning til udfyldelse af tilbudslisten un...
# 5283  udbud vedrørende madservice kontraktbilag 2 kr...
# 5284  kontraktbilag 3 kvalitetsstandard for madservi...
# 5285  kontraktbilag 4 kommunikation via omsorgssyste...
# 5286  servicebrev 06 11 2020 indberetningsfrister og...
# 5287   erhvervslejekontrakt ikke erhvervsbeskyttet m...
# 5288  udbud light regimet på levering af madservice ...
# 5289  varde kommune udbud af madservice delaftale 1 ...
# 5290  varde kommune udbud af madservice xx 2021 udbu...
#
#                                                    word  \
# 15    [danmark, københavn, reparation, vedligeholdel...
# 151   [danmark, københavn, reparation, vedligeholdel...
# 5273                                                 []
# 5274  [5, 592, carolineparken, leje, af, lokaler, st...
# 5275  [5, 592, carolineparken, leje, af, lokaler, st...
# 5276                                                 []
# 5277  [inventarliste, pr, marts, 2021, unnamed, 1, u...
# 5278  [bilag, 6, erhvervslejekontrakt, dok, nr, 2031...
# 5279  [tjekliste, erhvervslejeloven, denne, vejledni...
# 5280  [kontrakt, madservice, delaftale, 1, plejecent...
# 5281  [kontrakt, madservice, delaftale, 2, –, visite...
# 5282  [vejledning, til, udfyldelse, af, tilbudsliste...
# 5283  [udbud, vedrørende, madservice, kontraktbilag,...
# 5284  [kontraktbilag, 3, kvalitetsstandard, for, mad...
# 5285  [kontraktbilag, 4, kommunikation, via, omsorgs...
# 5286  [servicebrev, 06, 11, 2020, indberetningsfrist...
# 5287  [erhvervslejekontrakt, ikke, erhvervsbeskyttet...
# 5288  [udbud, light, regimet, på, levering, af, mads...
# 5289  [varde, kommune, udbud, af, madservice, delaft...
# 5290  [varde, kommune, udbud, af, madservice, xx, 20...
#
#                                                   lemmy  \
# 15    [danmark, københavn, reparation, vedligeholdel...
# 151   [danmark, københavn, reparation, vedligeholdel...
# 5273                                                 []
# 5274  [5, 592, carolinepark, leje, af, lokale, stork...
# 5275  [5, 592, carolinepark, leje, af, lokale, stork...
# 5276                                                 []
# 5277  [inventarliste, per, marts, 2021, unnamed, 1, ...
# 5278  [bilag, 6, erhvervslejekontrakt, dokke, nr, 20...
# 5279  [tjekliste, erhvervslejelov, denne, vejledning...
# 5280  [kontrakt, madservice, delaftale, 1, plejecent...
# 5281  [kontrakt, madservice, delaftale, 2, –, visite...
# 5282  [vejledning, til, udfyldelse, af, tilbudsliste...
# 5283  [udbud, vedrørende, madservice, kontraktbilag,...
# 5284  [kontraktbilag, 3., kvalitetsstandard, for, ma...
# 5285  [kontraktbilag, 4, kommunikation, via, omsorgs...
# 5286  [servicebrev, 06, 11, 2020, indberetningsfrist...
# 5287  [erhvervslejekontrakt, ikke, erhvervsbeskytte,...
# 5288  [udbud, light, regime, på, levering, af, madse...
# 5289  [varde, kommune, udbud, af, madservice, delaft...
# 5290  [varde, kommune, udbud, af, madservice, xx, 20...
#
#                     virksomhedsoverdragelse_2022_filter
# 15                                                   []
# 151                                                  []
# 5273                                                 []
# 5274                                                 []
# 5275                                                 []
# 5276                                                 []
# 5277                                                 []
# 5278                                                 []
# 5279                                                 []
# 5280  [virksomhedsoverdragelse, virksomhedsoverdrage...
# 5281                                                 []
# 5282                                                 []
# 5283                                                 []
# 5284                                                 []
# 5285                                                 []
# 5286                                                 []
# 5287                                                 []
# 5288  [virksomhedsoverdragelse, virksomhedsoverdrage...
# 5289                                                 []
# 5290                                                 []

# %%
def cleanSTOR(text):
    text = re.sub('\s\s+', ' ', str(text)) # tilføjer mellemrum ved nylinje
    text = re.sub("\n", "", text) #fjern nylinje
    text = re.sub("\r", " ", text) #fjern nylinje i doc
    text = re.sub("[()]","", text) # fjern parenteser
    text = re.sub("%", "", text) # fjern procent
    text = re.sub('[-()\"#/@;:<>{}`+=~|.!?,‰]', ' ', text) # fjerner specielle tegn og symboler
    #text = re.sub("\d", "", text) # fjern tal
    text = re.sub(' +', ' ', text) # fjern for mange mellemrum
    return text

# %%
corpus['clean_stor'] = corpus.text.apply(lambda x : cleanSTOR(x))

# %%
corpus.head()
# Out:
#                                                filename  \
# 15                          Udbudsresume 3672982021 pdf
# 151                         Udbudsresume 3672982021 pdf
# 5273  Erhvervslejekontrakt  Bilag 1  plantegning ove...
# 5274  Erhvervslejekontrakt  Bilag 2  stueplan 129286...
# 5275  Erhvervslejekontrakt  Bilag 3  kælderfacilitet...
#
#                                                    text  \
# 15    Danmark-København: Reparation, vedligeholdelse...
# 151   Danmark-København: Reparation, vedligeholdelse...
# 5273
#
# 5274  5-592\r\n\r\nCarolineparken - leje af lokaler\...
# 5275  5-592\r\n\r\nCarolineparken - leje af lokaler\...
#
#                                                 filedir  \
# 15    F:\contract-skills-and-performance\Download af...
# 151   F:\contract-skills-and-performance\Download af...
# 5273  F:\contract-skills-and-performance\Download af...
# 5274  F:\contract-skills-and-performance\Download af...
# 5275  F:\contract-skills-and-performance\Download af...
#
#                                              clean_text  \
# 15    danmark københavn reparation vedligeholdelse o...
# 151   danmark københavn reparation vedligeholdelse o...
# 5273
#
# 5274  5 592 carolineparken leje af lokaler storkøkke...
# 5275  5 592 carolineparken leje af lokaler storkøkke...
#
#                                                    word  \
# 15    [danmark, københavn, reparation, vedligeholdel...
# 151   [danmark, københavn, reparation, vedligeholdel...
# 5273                                                 []
# 5274  [5, 592, carolineparken, leje, af, lokaler, st...
# 5275  [5, 592, carolineparken, leje, af, lokaler, st...
#
#                                                   lemmy  \
# 15    [danmark, københavn, reparation, vedligeholdel...
# 151   [danmark, københavn, reparation, vedligeholdel...
# 5273                                                 []
# 5274  [5, 592, carolinepark, leje, af, lokale, stork...
# 5275  [5, 592, carolinepark, leje, af, lokale, stork...
#
#      virksomhedsoverdragelse_2022_filter  \
# 15                                    []
# 151                                   []
# 5273                                  []
# 5274                                  []
# 5275                                  []
#
#                                              clean_stor
# 15    Danmark København Reparation vedligeholdelse o...
# 151   Danmark København Reparation vedligeholdelse o...
# 5273
#
# 5274  5 592 Carolineparken leje af lokaler Storkøkke...
# 5275  5 592 Carolineparken leje af lokaler Storkøkke...

# %%
#corpus = corpus.drop(columns=['tema_2', 'tema_3', 'tema_4_1', 'tema_4_2', 'tema_4', 'tema_5', 'tema_6', 'tema_7_1', 'tema_7_2', 'tema_7', 'tema_8_1', 'tema_8_2', 'tema_8', 'tema_9', 'tema_10_1', 'tema_10_2', 'tema_10', 'tema_11', 'tema_12', 'tema_13_1', 'tema_13_2', 'tema_13', 'tema_14', 'tema_15', 'tema_16', 'tema_17', 'tema_18', 'tema_19', 'tema_20', 'tema_21', 'tema_22', 'tema_23_1', 'tema_23_2', 'tema_23', 'tema_24_x', 'tema_24_y', 'tema_24_1', 'tema_24_kontekst', 'tema_24', 'tema_25', 'tema_26_1', 'tema_26_kontekst', 'tema_26', 'tema_27', 'tema_28', 'tema_29', 'tema_x'])

# %%
#regel_1 = ['bekendtgørelsen om udbyderansvar', 'bekendtgørelse om udbyderansvar']

# %%
#def Filter1(clean_text, regel_1):
#    regel_1 = ('|'.join(regel_1))
#    clean_text = re.findall(regel_1, clean_text)
#    return clean_text

# %%
#corpus['tema_1'] = corpus.clean_text.apply(lambda x, y=regel_1 : Filter1(x, y))

# %%
regel_2 = ['ansættelsespapir', 'ansættelsesbrev', 'arbejdsbrev', 'ansættelseskontrakter', 'ansættelsesbevis']

# %%
def Filter2(lemmy, regel_2):
    return [n for n in lemmy if
             any(m in n for m in regel_2)]

# %%
corpus['tema_2'] = corpus.lemmy.apply(lambda x, y=regel_2 : Filter2(x, y))

# %%
regel_3_1 = ['medarbejderrepræsentant', 'arbejdsmiljørepræsentant']

# %%
regel_3_2 = [' AMR ', ' TRIO ']

# %%
def Filter3_1(lemmy, regel_3_1):
    return [n for n in lemmy if
             any(m in n for m in regel_3_1)]

# %%
def Filter3_2(clean_stor, regel_3_2):
    regel_3_2 = ('|'.join(regel_3_2))
    clean_stor = re.findall(regel_3_2, clean_stor)
    return clean_stor

# %%
corpus['tema_3_1'] = corpus.lemmy.apply(lambda x, y=regel_3_1 : Filter3_1(x, y))

# %%
corpus['tema_3_2'] = corpus.clean_stor.apply(lambda x, y=regel_3_2 : Filter3_2(x, y))

# %%
corpus['tema_3'] = corpus['tema_3_1'] + corpus['tema_3_2']

# %%
regel_4_1 = ['med udvalg', 'medudvalg', 'med udvalget', 'medudvalget', 'rammeaftale om medindflydelse og medbestemmelse','direktiv 299214EF', 'direktiv 2992 14 EF']

# %%
def Filter4_1(clean_text, regel_4_1):
    regel_4_1 = ('|'.join(regel_4_1))
    clean_text = re.findall(regel_4_1, clean_text)
    return clean_text

# %%
regel_4_2 = ['medindflyd', 'medarbejderhåndbog']

# %%
def Filter4_2(lemmy, regel_4_2):
    return [n for n in lemmy if
             any(m in n for m in regel_4_2)]

# %%
regel_4_3 = ['MED rammeaftale', 'MED rammeaftalen', 'MEDrammeaftale', 'MEDrammeaftalen']

# %%
def Filter4_3(clean_stor, regel_4_3):
    regel_4_3 = ('|'.join(regel_4_3))
    clean_stor = re.findall(regel_4_3, clean_stor)
    return clean_stor

# %%
corpus['tema_4_1'] = corpus.clean_text.apply(lambda x, y=regel_4_1 : Filter4_1(x, y))

# %%
corpus['tema_4_2'] = corpus.lemmy.apply(lambda x, y=regel_4_2 : Filter4_2(x, y))

# %%
corpus['tema_4_3'] = corpus.clean_stor.apply(lambda x, y=regel_4_3 : Filter4_3(x, y))

# %%
corpus['tema_4'] = corpus['tema_4_1'] + corpus['tema_4_2'] + corpus['tema_4_3']

# %%
regel_5 = ['arbejdsmiljøloven', 'arbejdstilsyn']

# %%
def Filter5(lemmy, regel_5):
    return [n for n in lemmy if
             any(m in n for m in regel_5)]

# %%
corpus['tema_5'] = corpus.lemmy.apply(lambda x, y=regel_5 : Filter5(x, y))

# %%
regel_6 = ['løn og ansættelsesforhold', 'løn og ansættelsesforholdet', 'løn og arbejdsvilkår']

# %%
def Filter6(clean_text, regel_6):
    regel_6 = ('|'.join(regel_6))
    clean_text = re.findall(regel_6, clean_text)
    return clean_text

# %%
corpus['tema_6'] = corpus.clean_text.apply(lambda x, y=regel_6 : Filter6(x, y))

# %%
regel_7_1 = ['ensidigt gentaget arbejde', 'tung løft']

# %%
regel_7_2 = ['sygefravær', 'personaleomsætning', 'arbejdsulykke', 'arbejdstid', 'mobning', 'overbelastning', 'allergimærk', 'ergono', 'nedslid', 'udbrænd', 'arbejdstempo', 'arbejdstakt']

# %%
regel_7_3 = [' EGA ']

# %%
def Filter7_3(clean_stor, regel_7_3):
    regel_7_3 = ('|'.join(regel_7_3))
    clean_stor = re.findall(regel_7_3, clean_stor)
    return clean_stor

# %%
def Filter7_2(lemmy, regel_7_2):
    return [n for n in lemmy if
             any(m in n for m in regel_7_2)]

# %%
def Filter7_1(clean_text, regel_7_1):
    regel_7_1 = ('|'.join(regel_7_1))
    clean_text = re.findall(regel_7_1, clean_text)
    return clean_text

# %%
corpus['tema_7_1'] = corpus.clean_text.apply(lambda x, y=regel_7_1 : Filter7_1(x, y))

# %%
corpus['tema_7_2'] = corpus.lemmy.apply(lambda x, y=regel_7_2 : Filter7_2(x, y))

# %%
corpus['tema_7_3'] = corpus.clean_stor.apply(lambda x, y=regel_7_3 : Filter7_3(x, y))

# %%
corpus['tema_7'] = corpus['tema_7_1'] + corpus['tema_7_2'] + corpus['tema_7_3']

# %%
regel_8_1 = ['kronesmiley', 'krone smiley', 'grøn smiley']

# %%
regel_8_2 = ['arbejdsmiljøledelse', 'miljøvejvis', 'arbejdsmiljøcertificering']

# %%
def Filter8_1(clean_text, regel_8_1):
    regel_8_1 = ('|'.join(regel_8_1))
    clean_text = re.findall(regel_8_1, clean_text)
    return clean_text

# %%
def Filter8_2(lemmy, regel_8_2):
    return [n for n in lemmy if
             any(m in n for m in regel_8_2)]

# %%
corpus['tema_8_1'] = corpus.clean_text.apply(lambda x, y=regel_8_1 : Filter8_1(x, y))

# %%
corpus['tema_8_2'] = corpus.lemmy.apply(lambda x, y=regel_8_2 : Filter8_2(x, y))

# %%
corpus['tema_8'] = corpus['tema_8_1'] + corpus['tema_8_2']

# %%
#regel_9 = [' csr ', 'corporate social responsibility']

# %%
#def Filter9(clean_text, regel_9):
#    regel_9 = ('|'.join(regel_9))
#    clean_text = re.findall(regel_9, clean_text)
#    return clean_text

# %%
#corpus['tema_9'] = corpus.clean_text.apply(lambda x, y=regel_9 : Filter9(x, y))

# %%
regel_10_1 = ['social klausul', 'sociale klausuler', 'social ansvar', 'socialt ansvar', 'socialt medansvar', 'global compact', ' etik ', ' etisk ']

# %%
regel_10_2 = ['ligestilling', 'diskrimination', 'samfundsansvar', 'etnisk', 'menneskerettighed' ]

# %%
def Filter10_1(clean_text, regel_10_1):
    regel_10_1 = ('|'.join(regel_10_1))
    clean_text = re.findall(regel_10_1, clean_text)
    return clean_text

# %%
def Filter10_2(lemmy, regel_10_2):
    return [n for n in lemmy if
             any(m in n for m in regel_10_2)]

# %%
corpus['tema_10_1'] = corpus.clean_text.apply(lambda x, y=regel_10_1 : Filter10_1(x, y))

# %%
corpus['tema_10_2'] = corpus.lemmy.apply(lambda x, y=regel_10_2 : Filter10_2(x, y))

# %%
corpus['tema_10'] = corpus['tema_10_1'] + corpus['tema_10_2']

# %%
regel_11 = ['fastholdelsespolitik', 'rekruttering']

# %%
def Filter11(lemmy, regel_11):
    return [n for n in lemmy if
             any(m in n for m in regel_11)]

# %%
corpus['tema_11'] = corpus.lemmy.apply(lambda x, y=regel_11 : Filter11(x, y))

# %%
regel_12 = ['uddannelsesklausul', 'videreuddannelse', 'mentor', 'uddannelsespolitik', 'kompetenceudvikling', 'opkvalificer', 'efteruddannelse', 'uddannelseskrav', 'uddannelsesaftale']

# %%
def Filter12(lemmy, regel_12):
    return [n for n in lemmy if
             any(m in n for m in regel_12)]

# %%
corpus['tema_12'] = corpus.lemmy.apply(lambda x, y=regel_12 : Filter12(x, y))

# %%
regel_13_1 = [' MUS ']

# %%
regel_13_2 = ['medarbejderudviklingssamtal']

# %%
def Filter13_1(clean_stor, regel_13_1):
    regel_13_1 = ('|'.join(regel_13_1))
    clean_stor = re.findall(regel_13_1, clean_stor)
    return clean_stor

# %%
def Filter13_2(lemmy, regel_13_2):
    return [n for n in lemmy if
             any(m in n for m in regel_13_2)]

# %%
corpus['tema_13_1'] = corpus.clean_stor.apply(lambda x, y=regel_13_1 : Filter13_1(x, y))

# %%
corpus['tema_13_2'] = corpus.lemmy.apply(lambda x, y=regel_13_2 : Filter13_2(x, y))

# %%
corpus['tema_13'] = corpus['tema_13_1'] + corpus['tema_13_2']

# %%
#regel_14 = [' ilo ', 'international labour organisation']

# %%
#def Filter14(clean_text, regel_14):
#    regel_14 = ('|'.join(regel_14))
#    clean_text = re.findall(regel_14, clean_text)
#    return clean_text

# %%
#corpus['tema_14'] = corpus.clean_text.apply(lambda x, y=regel_14 : Filter14(x, y))

# %%
regel_15 = ['tvangsarbejde', 'ilokonvention nr 29', 'ilo konvention nr 29', 'ilokonvention nr 105', 'ilo konvention nr 105']

# %%
def Filter15(clean_text, regel_15):
    regel_15 = ('|'.join(regel_15))
    clean_text = re.findall(regel_15, clean_text)
    return clean_text

# %%
corpus['tema_15'] = corpus.clean_text.apply(lambda x, y=regel_15 : Filter15(x, y))

# %%
regel_16 = ['kontrakthavers pligt til at sikre dennes ansattes vilkår', 'ilokonventionen nr 94', 'ilo konventionen nr 94']

# %%
def Filter16(clean_text, regel_16):
    regel_16 = ('|'.join(regel_16))
    clean_text = re.findall(regel_16, clean_text)
    return clean_text

# %%
corpus['tema_16'] = corpus.clean_text.apply(lambda x, y=regel_16 : Filter16(x, y))

# %%
regel_17 = ['ingen diskrimination i ansættelsen', 'ilokonvention nr 100', 'ilo konvention nr 100', 'ilokonvention nr 111', 'ilo konvention nr 111']

# %%
def Filter17(clean_text, regel_17):
    regel_17 = ('|'.join(regel_17))
    clean_text = re.findall(regel_17, clean_text)
    return clean_text

# %%
corpus['tema_17'] = corpus.clean_text.apply(lambda x, y=regel_17 : Filter17(x, y))

# %%
regel_18 = ['mindstealder for adgang til beskæftigelse samt forbud mod og omgående indsats til afskaffelse af de værste former for børnearbejde', 'ilokonvention nr 138', 'ilo konvention nr 138', 'ilokonvention nr 182', 'ilo konvention nr 182']

# %%
def Filter18(clean_text, regel_18):
    regel_18 = ('|'.join(regel_18))
    clean_text = re.findall(regel_18, clean_text)
    return clean_text

# %%
corpus['tema_18'] = corpus.clean_text.apply(lambda x, y=regel_18 : Filter18(x, y))

# %%
regel_19 = ['sikkert og sundt arbejdsmiljø', 'ilokonvention nr 155', 'ilo konvention nr 155']

# %%
def Filter19(clean_text, regel_19):
    regel_19 = ('|'.join(regel_19))
    clean_text = re.findall(regel_19, clean_text)
    return clean_text

# %%
corpus['tema_19'] = corpus.clean_text.apply(lambda x, y=regel_19 : Filter19(x, y))

# %%
regel_20 = ['organisationsfrihed og ret til kollektive forhandlinger', 'ilokonvention nr 87', 'ilo konvention nr 87', 'ilokonvention nr 98', 'ilo konvention nr 98', 'ilokonvention nr 135', 'ilo konvention nr 135']

# %%
def Filter20(clean_text, regel_20):
    regel_20 = ('|'.join(regel_20))
    clean_text = re.findall(regel_20, clean_text)
    return clean_text

# %%
corpus['tema_20'] = corpus.clean_text.apply(lambda x, y=regel_20 : Filter20(x, y))

# %%
# regel_21 = ['ansættelsespapir', 'ansættelsesbrev', 'arbejdsbrev', 'ansættelseskontrakter', 'ansættelsesbevis']

# %%
#def Filter21(lemmy, regel_21):
#    return [n for n in lemmy if
#             any(m in n for m in regel_21)]

# %%
#corpus['tema_21'] = corpus.lemmy.apply(lambda x, y=regel_21 : Filter21(x, y))

# %%
regel_22 = ['liste med medarbejdere', 'oversigt over medarbejde', 'medarbejderoversigt', 'medarbejderoversigter', 'medarbejderoversigten']

# %%
def Filter22(clean_text, regel_22):
    regel_22 = ('|'.join(regel_22))
    clean_text = re.findall(regel_22, clean_text)
    return clean_text

# %%
corpus['tema_22'] = corpus.clean_text.apply(lambda x, y=regel_22 : Filter22(x, y))

# %%
regel_23_1 = ['forsikring af medarbejde', 'forsikring af ansatte', 'forsikring af person']

# %%
regel_23_2 = ['arbejdsskadeforsikring']

# %%
def Filter23_1(clean_text, regel_23_1):
    regel_23_1 = ('|'.join(regel_23_1))
    clean_text = re.findall(regel_23_1, clean_text)
    return clean_text

# %%
def Filter23_2(lemmy, regel_23_2):
    return [n for n in lemmy if
             any(m in n for m in regel_23_2)]

# %%
corpus['tema_23_1'] = corpus.clean_text.apply(lambda x, y=regel_23_1 : Filter23_1(x, y))

# %%
corpus['tema_23_2'] = corpus.lemmy.apply(lambda x, y=regel_23_2 : Filter23_2(x, y))

# %%
corpus['tema_23'] = corpus['tema_23_1'] + corpus['tema_23_2']

# %%
def get_context(text, w, left, right):
    all_contexts = []
    for i in range(len(text)):
        if re.match(w,text[i], 0):
            if i < left:
                context_left = text[:i]
            else:
                context_left = text[i-left:i]
            if len(text) < (i+right):
                context_right = text[i:]
            else:
                context_right = text[i:(i+right+1)]
            context = context_left + context_right
            all_contexts.append(context)
    return all_contexts

# %%
regel_24 = ['ophævelse af kontrakt', 'ophæv kontrakt', 'ophæves kontrakt', ' bod ', 'sanktioner', 'sanktion', 'sankttionere', 'misligholdelse', 'bonus']

# %%
def Filter24(clean_text, regel_24):
    regel_24 = ('|'.join(regel_24))
    clean_text = re.findall(regel_24, clean_text)
    return clean_text

# %%
corpus['tema_24_1'] = corpus.lemmy.apply(lambda text, w='|'.join(regel_24), left=6, right=6 : get_context(text, w, left, right))

# %%
betingelse = ['klausul', 'arbejdsmiljø', 'arbejdsforhold', 'arbejdsvilkår']

# %%
def listoflist (tema_24_1):
    flatList = [ item for elem in tema_24_1 for item in elem]
    return flatList

# %%
corpus['tema_24_kontekst'] = corpus.tema_24_1.apply(lambda x : listoflist(x))

# %%
def kriterium(tema_24_kontekst, betingelse):
    return [n for n in tema_24_kontekst if
             any(m in n for m in betingelse)]

# %%
corpus['tema_24'] = corpus.tema_24_kontekst.apply(lambda x, y=betingelse : kriterium(x, y))

# %%
corpus['tema_24_kontrol'] = corpus.clean_text.apply(lambda x, y=regel_24 : Filter24(x, y))

# %%
regel_25_1 = ['samarbejd', 'medansvar', 'kommunik', 'tillid', 'dialog', 'informe', 'inddrage', 'dialogklausul']

# %%
def Filter25_1(lemmy, regel_25_1):
    return [n for n in lemmy if
             any(m in n for m in regel_25_1)]

# %%
corpus['tema_25_1'] =corpus.lemmy.apply(lambda text, w='|'.join(regel_25_1), left=6, right=6 : get_context(text, w, left, right))

# %%
betingelse = ['klausul', 'arbejdsmiljø', 'arbejdsforhold', 'arbejdsvilkår']

# %%
def listoflist (tema_25_1):
    flatList = [ item for elem in tema_25_1 for item in elem]
    return flatList

# %%
corpus['tema_25_kontekst'] = corpus.tema_25_1.apply(lambda x : listoflist(x))

# %%
def kriterium(tema_25_kontekst, betingelse):
    return [n for n in tema_25_kontekst if
             any(m in n for m in betingelse)]

# %%
corpus['tema_25'] = corpus.tema_25_kontekst.apply(lambda x, y=betingelse : kriterium(x, y))

# %%
corpus['tema_25_kontrol'] = corpus.lemmy.apply(lambda x, y=regel_25_1 : Filter25_1(x, y))

# %%
regel_26 = ['opgave']

# %%
def Filter26(lemmy, regel_26):
    return [n for n in lemmy if
             any(m in n for m in regel_26)]

# %%
corpus['tema_26_1'] = corpus.lemmy.apply(lambda text, w='|'.join(regel_26), left=6, right=6 : get_context(text, w, left, right))

# %%
betingelse = ['klausul', 'arbejdsmiljø', 'arbejdsforhold', 'arbejdsvilkår']

# %%
def listoflist (tema_26_1):
    flatList = [ item for elem in tema_26_1 for item in elem]
    return flatList

# %%
corpus['tema_26_kontekst'] = corpus.tema_26_1.apply(lambda x : listoflist(x))

# %%
def kriterium(tema_26_kontekst, betingelse):
    return [n for n in tema_26_kontekst if
             any(m in n for m in betingelse)]

# %%
corpus['tema_26'] = corpus.tema_26_kontekst.apply(lambda x, y=betingelse : kriterium(x, y))

# %%
corpus['tema_26_kontrol'] = corpus.lemmy.apply(lambda x, y=regel_26 : Filter26(x, y))

# %%
regel_27_1 = ['3F', 'FOA', 'HK', 'OAO', ' FH ']

# %%
regel_27_2 = ['fagforening', 'fagforeningen', 'fagforeninger', 'dansk metal', 'ny udbudsmodel', 'treiét udbud', 'treiet udbud', 'tre i ét udbud', 'tre i et udbud', 'faglige organisation', 'faglige organisationer', 'faglig organisation', 'faglig organisatoner']

# %%
def Filter27_1(clean_stor, regel_27_1):
    regel_27_1 = ('|'.join(regel_27_1))
    clean_stor = re.findall(regel_27_1, clean_stor)
    return clean_stor

# %%
def Filter27_2(clean_text, regel_27_2):
    regel_27_2 = ('|'.join(regel_27_2))
    clean_text = re.findall(regel_27_2, clean_text)
    return clean_text

# %%
corpus['tema_27_1'] = corpus.clean_stor.apply(lambda x, y=regel_27_1 : Filter27_1(x, y))

# %%
corpus['tema_27_2'] = corpus.clean_text.apply(lambda x, y=regel_27_2 : Filter27_2(x, y))

# %%
corpus['tema_27'] = corpus['tema_27_1'] + corpus['tema_27_2']

# %%
regel_28_1 = [' RUT ']

# %%
regel_28_2 = ['kædeansvar']

# %%
def Filter28_1(clean_stor, regel_28_1):
    regel_28_1 = ('|'.join(regel_28_1))
    clean_stor = re.findall(regel_28_1, clean_stor)
    return clean_stor

# %%
def Filter28_2(lemmy, regel_28_2):
    return [n for n in lemmy if
             any(m in n for m in regel_28_2)]

# %%
corpus['tema_28_1'] = corpus.clean_stor.apply(lambda x, y=regel_28_1 : Filter28_1(x, y))

# %%
corpus['tema_28_2'] = corpus.lemmy.apply(lambda x, y=regel_28_2 : Filter28_2(x, y))

# %%
corpus['tema_28'] = corpus['tema_28_1'] + corpus['tema_28_2']

# %%
regel_29 = ['lønrefusion', 'medarbejdersrefusion', 'medarbejdsrefusion' 'sygdagpengerefusion']

# %%
def Filter29(lemmy, regel_29):
    return [n for n in lemmy if
             any(m in n for m in regel_29)]

# %%
corpus['tema_29'] = corpus.lemmy.apply(lambda x, y=regel_29 : Filter29(x, y))

# %%
regel_33_1 = ['rekrutteringspolitik', 'afskedigelsespolitik', 'udviklingspolitik', 'mobbepolitik', 'stresspolitik', 'seniorpolitik', 'personalepolitik']

# %%
regel_33_2 = ['hr politik', 'hrpolitik']

# %%
def Filter33_1(lemmy, regel_33_1):
    return [n for n in lemmy if
             any(m in n for m in regel_33_1)]

# %%
def Filter33_2(clean_text, regel_33_2):
    regel_33_2 = ('|'.join(regel_33_2))
    clean_text = re.findall(regel_33_2, clean_text)
    return clean_text

# %%
corpus['tema_33_1'] = corpus.lemmy.apply(lambda x, y=regel_33_1 : Filter33_1(x, y))

# %%
corpus['tema_33_2'] = corpus.clean_text.apply(lambda x, y=regel_33_2 : Filter33_2(x, y))

# %%
corpus['tema_33'] = corpus['tema_33_1'] + corpus['tema_33_2']

# %%
regel_34 = ['kontrolforanstaltning', 'stikprøv', 'oplysningsforpligtelse']

# %%
def Filter34(lemmy, regel_34):
    return [n for n in lemmy if
             any(m in n for m in regel_34)]

# %%
corpus['tema_34_1'] = corpus.lemmy.apply(lambda text, w='|'.join(regel_34), left=6, right=6 : get_context(text, w, left, right))

# %%
betingelse = ['klausul', 'arbejdsmiljø', 'arbejdsforhold', 'arbejdsvilkår']

# %%
def listoflist (tema_34_1):
    flatList = [ item for elem in tema_34_1 for item in elem]
    return flatList

# %%
corpus['tema_34_kontekst'] = corpus.tema_34_1.apply(lambda x : listoflist(x))

# %%
def kriterium(tema_34_kontekst, betingelse):
    return [n for n in tema_34_kontekst if
             any(m in n for m in betingelse)]

# %%
corpus['tema_34'] = corpus.tema_34_kontekst.apply(lambda x, y=betingelse : kriterium(x, y))

# %%
corpus['tema_34_kontrol'] = corpus.lemmy.apply(lambda x, y=regel_34 : Filter34(x, y))

# %%
regel_35 = ['arbejdsklausul', 'arbejdsmiljøklausul']

# %%
def Filter35(lemmy, regel_35):
    return [n for n in lemmy if
             any(m in n for m in regel_35)]

# %%
corpus['tema_35'] = corpus.lemmy.apply(lambda x, y=regel_35 : Filter35(x, y))

# %%
regel_36 = ['samarbejdsudvalg']

# %%
def Filter36(lemmy, regel_36):
    return [n for n in lemmy if
             any(m in n for m in regel_36)]

# %%
corpus['tema_36'] = corpus.lemmy.apply(lambda x, y=regel_36 : Filter36(x, y))

# %%
corpus.to_csv("virksomhedsoverdragelser_tema_version3.csv", mode = 'w', columns=['filename', 'filedir', 'tema_2', 'tema_3', 'tema_4', 'tema_5', 'tema_6', 'tema_7', 'tema_8', 'tema_10', 'tema_11', 'tema_12', 'tema_13', 'tema_15', 'tema_16', 'tema_17', 'tema_18', 'tema_19', 'tema_20', 'tema_22', 'tema_23', 'tema_24', 'tema_24_kontrol', 'tema_25', 'tema_25_kontrol', 'tema_26', 'tema_26_kontrol', 'tema_27', 'tema_28', 'tema_29', 'tema_33', 'tema_34', 'tema_34_kontrol', 'tema_35'], index=False)

# %%
corpus.to_pickle("virksomhedsoverdragelser_tema_tilpasninger.pkl")

# %%
corpus.to_csv("virksomhedsoverdragelser_tema_ekstra.csv", mode = 'w', columns=['filename', 'filedir', 'tema_12', 'tema_36'], index=False)

# %%
corpus.head(20)
# Out:
#                                                filename  \
# 15                          Udbudsresume 3672982021 pdf
# 151                         Udbudsresume 3672982021 pdf
# 5273  Erhvervslejekontrakt  Bilag 1  plantegning ove...
# 5274  Erhvervslejekontrakt  Bilag 2  stueplan 129286...
# 5275  Erhvervslejekontrakt  Bilag 3  kælderfacilitet...
# 5276  Erhvervslejekontrakt  Bilag 4 Fotooversigt 129...
# 5277  Erhvervslejekontrakt  Bilag 5  Inventarliste o...
# 5278  Erhvervslejekontrakt  Bilag 6  lejeberegning 1...
# 5279  Erhvervslejekontrakt  Byog Boligministeriets c...
# 5280  Kontrakt  Delaftale 1  Madservice Plejecentren...
# 5281  Kontrakt  Delaftale 2  Madservice til visitere...
# 5282  Kontraktbilag 1  Tilbudsliste XLSX 1292862021 ...
# 5283  Kontraktbilag 2  Kravspecifikationer DOCX 1292...
# 5284  Kontraktbilag 3  Kvalitetsstandard DOCX 129286...
# 5285  Kontraktbilag 4  Kommunikation via omsorgssyst...
# 5286  Kontraktbilag 5  Tidsfrist aflevering til UDK ...
# 5287  Kontraktbilag 6  Erhvervslejekontrakt  Carolin...
# 5288  Udbudsbetingelser Madservice DOCX 1292862021 docx
# 5289  Udbudsbilag 1  Delaftale 1  Tilbudsbesvarelse ...
# 5290  Udbudsbilag 2  Delaftale 2  Tilbudsbesvarelse ...
#
#                                                    text  \
# 15    Danmark-København: Reparation, vedligeholdelse...
# 151   Danmark-København: Reparation, vedligeholdelse...
# 5273
#
# 5274  5-592\r\n\r\nCarolineparken - leje af lokaler\...
# 5275  5-592\r\n\r\nCarolineparken - leje af lokaler\...
# 5276
#
# 5277                             Inventarliste pr. m...
# 5278  Bilag 6\r\nErhvervslejekontrakt\r\n\r\nDok.nr....
# 5279  Tjekliste - Erhvervslejeloven\r\nDenne vejledn...
# 5280  Kontrakt Madservice \n\nDelaftale 1 - Plejecen...
# 5281  Kontrakt Madservice \n\nDelaftale 2 – Visitere...
# 5282                                                ...
# 5283  Udbud vedrørende Madservice\t    \n\n         ...
# 5284  Kontraktbilag 3 - Kvalitetsstandard for Madser...
# 5285  Kontraktbilag 4 - Kommunikation via omsorgssys...
# 5286  Servicebrev 06.11.2020 Indberetningsfrister og...
# 5287  \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n      ...
# 5288  Udbud\n\n\n\n\n\nLight regimet\n\n\n\nPå lever...
# 5289  Varde Kommune, Udbud af madservice\t\tDelaftal...
# 5290  Varde Kommune, Udbud af madservice\t\txx 2021\...
#
#                                                 filedir  \
# 15    F:\contract-skills-and-performance\Download af...
# 151   F:\contract-skills-and-performance\Download af...
# 5273  F:\contract-skills-and-performance\Download af...
# 5274  F:\contract-skills-and-performance\Download af...
# 5275  F:\contract-skills-and-performance\Download af...
# 5276  F:\contract-skills-and-performance\Download af...
# 5277  F:\contract-skills-and-performance\Download af...
# 5278  F:\contract-skills-and-performance\Download af...
# 5279  F:\contract-skills-and-performance\Download af...
# 5280  F:\contract-skills-and-performance\Download af...
# 5281  F:\contract-skills-and-performance\Download af...
# 5282  F:\contract-skills-and-performance\Download af...
# 5283  F:\contract-skills-and-performance\Download af...
# 5284  F:\contract-skills-and-performance\Download af...
# 5285  F:\contract-skills-and-performance\Download af...
# 5286  F:\contract-skills-and-performance\Download af...
# 5287  F:\contract-skills-and-performance\Download af...
# 5288  F:\contract-skills-and-performance\Download af...
# 5289  F:\contract-skills-and-performance\Download af...
# 5290  F:\contract-skills-and-performance\Download af...
#
#                                              clean_text  \
# 15    danmark københavn reparation vedligeholdelse o...
# 151   danmark københavn reparation vedligeholdelse o...
# 5273
#
# 5274  5 592 carolineparken leje af lokaler storkøkke...
# 5275  5 592 carolineparken leje af lokaler storkøkke...
# 5276
#
# 5277   inventarliste pr marts 2021 unnamed 1 unnamed...
# 5278  bilag 6 erhvervslejekontrakt dok nr 20318 21 s...
# 5279  tjekliste erhvervslejeloven denne vejledning e...
# 5280  kontrakt madservice delaftale 1 plejecentre 23...
# 5281  kontrakt madservice delaftale 2 – visitere hje...
# 5282   vejledning til udfyldelse af tilbudslisten un...
# 5283  udbud vedrørende madservice kontraktbilag 2 kr...
# 5284  kontraktbilag 3 kvalitetsstandard for madservi...
# 5285  kontraktbilag 4 kommunikation via omsorgssyste...
# 5286  servicebrev 06 11 2020 indberetningsfrister og...
# 5287   erhvervslejekontrakt ikke erhvervsbeskyttet m...
# 5288  udbud light regimet på levering af madservice ...
# 5289  varde kommune udbud af madservice delaftale 1 ...
# 5290  varde kommune udbud af madservice xx 2021 udbu...
#
#                                                    word  \
# 15    [danmark, københavn, reparation, vedligeholdel...
# 151   [danmark, københavn, reparation, vedligeholdel...
# 5273                                                 []
# 5274  [5, 592, carolineparken, leje, af, lokaler, st...
# 5275  [5, 592, carolineparken, leje, af, lokaler, st...
# 5276                                                 []
# 5277  [inventarliste, pr, marts, 2021, unnamed, 1, u...
# 5278  [bilag, 6, erhvervslejekontrakt, dok, nr, 2031...
# 5279  [tjekliste, erhvervslejeloven, denne, vejledni...
# 5280  [kontrakt, madservice, delaftale, 1, plejecent...
# 5281  [kontrakt, madservice, delaftale, 2, –, visite...
# 5282  [vejledning, til, udfyldelse, af, tilbudsliste...
# 5283  [udbud, vedrørende, madservice, kontraktbilag,...
# 5284  [kontraktbilag, 3, kvalitetsstandard, for, mad...
# 5285  [kontraktbilag, 4, kommunikation, via, omsorgs...
# 5286  [servicebrev, 06, 11, 2020, indberetningsfrist...
# 5287  [erhvervslejekontrakt, ikke, erhvervsbeskyttet...
# 5288  [udbud, light, regimet, på, levering, af, mads...
# 5289  [varde, kommune, udbud, af, madservice, delaft...
# 5290  [varde, kommune, udbud, af, madservice, xx, 20...
#
#                                                   lemmy  \
# 15    [danmark, københavn, reparation, vedligeholdel...
# 151   [danmark, københavn, reparation, vedligeholdel...
# 5273                                                 []
# 5274  [5, 592, carolinepark, leje, af, lokale, stork...
# 5275  [5, 592, carolinepark, leje, af, lokale, stork...
# 5276                                                 []
# 5277  [inventarliste, per, marts, 2021, unnamed, 1, ...
# 5278  [bilag, 6, erhvervslejekontrakt, dokke, nr, 20...
# 5279  [tjekliste, erhvervslejelov, denne, vejledning...
# 5280  [kontrakt, madservice, delaftale, 1, plejecent...
# 5281  [kontrakt, madservice, delaftale, 2, –, visite...
# 5282  [vejledning, til, udfyldelse, af, tilbudsliste...
# 5283  [udbud, vedrørende, madservice, kontraktbilag,...
# 5284  [kontraktbilag, 3., kvalitetsstandard, for, ma...
# 5285  [kontraktbilag, 4, kommunikation, via, omsorgs...
# 5286  [servicebrev, 06, 11, 2020, indberetningsfrist...
# 5287  [erhvervslejekontrakt, ikke, erhvervsbeskytte,...
# 5288  [udbud, light, regime, på, levering, af, madse...
# 5289  [varde, kommune, udbud, af, madservice, delaft...
# 5290  [varde, kommune, udbud, af, madservice, xx, 20...
#
#                     virksomhedsoverdragelse_2022_filter  \
# 15                                                   []
# 151                                                  []
# 5273                                                 []
# 5274                                                 []
# 5275                                                 []
# 5276                                                 []
# 5277                                                 []
# 5278                                                 []
# 5279                                                 []
# 5280  [virksomhedsoverdragelse, virksomhedsoverdrage...
# 5281                                                 []
# 5282                                                 []
# 5283                                                 []
# 5284                                                 []
# 5285                                                 []
# 5286                                                 []
# 5287                                                 []
# 5288  [virksomhedsoverdragelse, virksomhedsoverdrage...
# 5289                                                 []
# 5290                                                 []
#
#                                              clean_stor tema_2 tema_3_1  ...  \
# 15    Danmark København Reparation vedligeholdelse o...     []       []  ...
# 151   Danmark København Reparation vedligeholdelse o...     []       []  ...
# 5273
#      []       []  ...
# 5274  5 592 Carolineparken leje af lokaler Storkøkke...     []       []  ...
# 5275  5 592 Carolineparken leje af lokaler Storkøkke...     []       []  ...
# 5276
#      []       []  ...
# 5277   Inventarliste pr marts 2021 Unnamed 1 Unnamed...     []       []  ...
# 5278  Bilag 6 Erhvervslejekontrakt Dok nr 20318 21 S...     []       []  ...
# 5279  Tjekliste Erhvervslejeloven Denne vejledning e...     []       []  ...
# 5280  Kontrakt Madservice Delaftale 1 Plejecentre 23...     []       []  ...
# 5281  Kontrakt Madservice Delaftale 2 – Visitere hje...     []       []  ...
# 5282   Vejledning til udfyldelse af tilbudslisten Un...     []       []  ...
# 5283  Udbud vedrørende Madservice Kontraktbilag 2 Kr...     []       []  ...
# 5284  Kontraktbilag 3 Kvalitetsstandard for Madservi...     []       []  ...
# 5285  Kontraktbilag 4 Kommunikation via omsorgssyste...     []       []  ...
# 5286  Servicebrev 06 11 2020 Indberetningsfrister og...     []       []  ...
# 5287   ERHVERVSLEJEKONTRAKT Ikke erhvervsbeskyttet m...     []       []  ...
# 5288  Udbud Light regimet På levering af Madservice ...     []       []  ...
# 5289  Varde Kommune Udbud af madservice Delaftale 1 ...     []       []  ...
# 5290  Varde Kommune Udbud af madservice xx 2021 Udbu...     []       []  ...
#
#      tema_29 tema_33_1 tema_33_2 tema_33  \
# 15        []        []        []      []
# 151       []        []        []      []
# 5273      []        []        []      []
# 5274      []        []        []      []
# 5275      []        []        []      []
# 5276      []        []        []      []
# 5277      []        []        []      []
# 5278      []        []        []      []
# 5279      []        []        []      []
# 5280      []        []        []      []
# 5281      []        []        []      []
# 5282      []        []        []      []
# 5283      []        []        []      []
# 5284      []        []        []      []
# 5285      []        []        []      []
# 5286      []        []        []      []
# 5287      []        []        []      []
# 5288      []        []        []      []
# 5289      []        []        []      []
# 5290      []        []        []      []
#
#                                               tema_34_1  \
# 15                                                   []
# 151                                                  []
# 5273                                                 []
# 5274                                                 []
# 5275                                                 []
# 5276                                                 []
# 5277                                                 []
# 5278                                                 []
# 5279                                                 []
# 5280  [[–, uden, beregning, –, at, foretage, stikprø...
# 5281  [[–, uden, beregning, –, at, foretage, stikprø...
# 5282                                                 []
# 5283                                                 []
# 5284                                                 []
# 5285                                                 []
# 5286                                                 []
# 5287                                                 []
# 5288                                                 []
# 5289                                                 []
# 5290                                                 []
#
#                                        tema_34_kontekst tema_34  \
# 15                                                   []      []
# 151                                                  []      []
# 5273                                                 []      []
# 5274                                                 []      []
# 5275                                                 []      []
# 5276                                                 []      []
# 5277                                                 []      []
# 5278                                                 []      []
# 5279                                                 []      []
# 5280  [–, uden, beregning, –, at, foretage, stikprøv...      []
# 5281  [–, uden, beregning, –, at, foretage, stikprøv...      []
# 5282                                                 []      []
# 5283                                                 []      []
# 5284                                                 []      []
# 5285                                                 []      []
# 5286                                                 []      []
# 5287                                                 []      []
# 5288                                                 []      []
# 5289                                                 []      []
# 5290                                                 []      []
#
#              tema_34_kontrol  \
# 15                        []
# 151                       []
# 5273                      []
# 5274                      []
# 5275                      []
# 5276                      []
# 5277                      []
# 5278                      []
# 5279                      []
# 5280  [stikprøve, stikprøve]
# 5281  [stikprøve, stikprøve]
# 5282                      []
# 5283                      []
# 5284                      []
# 5285                      []
# 5286                      []
# 5287                      []
# 5288                      []
# 5289                      []
# 5290                      []
#
#                                                 tema_35 tema_36
# 15                                                   []      []
# 151                                                  []      []
# 5273                                                 []      []
# 5274                                                 []      []
# 5275                                                 []      []
# 5276                                                 []      []
# 5277                                                 []      []
# 5278                                                 []      []
# 5279                                                 []      []
# 5280  [arbejdsklausulere, arbejdsklausul, arbejdskla...      []
# 5281  [arbejdsklausulere, arbejdsklausul, arbejdskla...      []
# 5282                                                 []      []
# 5283                                                 []      []
# 5284                                                 []      []
# 5285                                                 []      []
# 5286                                                 []      []
# 5287                                                 []      []
# 5288                                                 []      []
# 5289                                                 []      []
# 5290                                                 []      []
#
# [20 rows x 70 columns]

# %%
corpus = corpus.reset_index(drop=True)

# %%
corpus[corpus['filename'].str.contains("IT Drift aftale 1599612021")]
# Out:
#                            filename  \
# 164  IT Drift aftale 1599612021 pdf
#
#                                                   text  \
# 164  AFTALE VEDRØRENDE\r\nDrift, vedligeholdelse, s...
#
#                                                filedir  \
# 164  F:\contract-skills-and-performance\Download af...
#
#                                             clean_text  \
# 164  aftale vedrørende drift vedligeholdelse suppor...
#
#                                                   word  \
# 164  [aftale, vedrørende, drift, vedligeholdelse, s...
#
#                                                  lemmy  \
# 164  [aftale, vedrørende, drifte, vedligeholdelse, ...
#
#                    virksomhedsoverdragelse_2022_filter tema_1 tema_2 tema_3  \
# 164  [virksomhedsoverdragelse, virksomhedsoverdrage...     []     []     []
#
#     tema_4_1 tema_4_2 tema_4                            tema_5  \
# 164       []       []     []  [personalepolitik, arbejdsmiljø]
#
#                                                 tema_6 tema_7_1 tema_7_2  \
# 164  [overenskomst, overenskomst, løn og ansættelse...       []       []
#
#     tema_7 tema_8_1 tema_8_2 tema_8 tema_9  \
# 164     []       []       []     []     []
#
#                                             tema_10_1  \
# 164  [social klausul, global compact, social klausul]
#
#                                   tema_10_2  \
# 164  [etnisk, etnisk, aldersdiskrimination]
#
#                                                tema_10 tema_11  \
# 164  [social klausul, global compact, social klausu...      []
#
#                                                tema_12 tema_13_1 tema_13_2  \
# 164  [uddannelsesklausul, uddannelsesklausul, lærli...        []        []
#
#     tema_13                                            tema_14  \
# 164      []  [ ilo ,  ilo ,  ilo ,  ilo ,  ilo ,  ilo ,  ilo ]
#
#                                    tema_15 tema_16                  tema_17  \
# 164  [tvangsarbejde, ilo konvention nr 29]      []  [ilo konvention nr 100]
#
#                      tema_18                          tema_19  \
# 164  [ilo konvention nr 138]  [sikkert og sundt arbejdsmiljø]
#
#                     tema_20 tema_21                     tema_22 tema_23_1  \
# 164  [ilo konvention nr 87]      []  [oversigt over medarbejde]        []
#
#     tema_23_2 tema_23                                          tema_24_x  \
# 164        []      []  [ bod ,  bod ,  bod ,  bod ,  bod ,  bod ,  bo...
#
#                                              tema_24_y  \
# 164  [misligholdelse, misligholdelsesbeføjelse, mis...
#
#                                              tema_24_1  \
# 164  [[aftale, vedrørende, drifte, vedligeholdelse,...
#
#                                       tema_24_kontekst  \
# 164  [aftale, vedrørende, drifte, vedligeholdelse, ...
#
#                                                tema_24  \
# 164  [klausul, arbejdsklausul, uddannelsesklausul, ...
#
#                                                tema_25 tema_26_1  \
# 164  [samarbejdsorganisation, samarbejde, informere...        []
#
#     tema_26_kontekst tema_26 tema_27  tema_28 tema_29 tema_x
# 164               []      []      []  [ rut ]      []     []

# %%
pd.set_option('display.max_columns', None)
